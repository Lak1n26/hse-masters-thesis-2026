# %% [markdown]
# # SASRec (Self-Attentive Sequential Recommendation)

# %%
import pandas as pd
import numpy as np
from tecd_retail_recsys.models import SASRec
from tecd_retail_recsys.metrics import calculate_metrics

import matplotlib.pyplot as plt

# %%
# !python3 run_sasrec.py prepare
# Out:
# ================================================================================
# STEP 1: Preparing data for SASRec
# ================================================================================
# Running data preprocessing...
# Starting data preprocessing...
# Loading events from t_ecd_small_partial/dataset/small/retail/events
# Loaded 236,479,226 total events
# Loading items data from t_ecd_small_partial/dataset/small/retail/items.pq
# Loaded 250,171 items with features: ['item_id', 'item_brand_id', 'item_category', 'item_subcategory', 'item_price', 'item_embedding']
# Merged item features. Data shape: (236479226, 12)
# Filtered to 3,758,762 events with action_type='added-to-cart'
# After filtering (min_user_interactions=1, min_item_interactions=20): 3,249,972 events, 84,944 users, 30,954 items
# Created mappings: 84944 users, 30954 items
# Temporal split - Train: days < 1269 (902,543 events), Val: days 1269-1288 (228,339 events), Test: days >= 1289 (223,395 events)
# Users in each part (train, val, test) - 7425
# Grouping data by users...
# Saving grouped data to processed_data/...
# Saved data for 84944 users and 30954 items
# Train: 7425 users
# Val: 7425 users
# Test: 7425 users
#
# ✓ Data preparation completed!

# %%
# !python3 tecd_retail_recsys/models/sasrec/train.py --exp_name=sasrec_v2 --num_epochs=100 --device=mps --batch_size=128 --max_seq_len=64 --embedding_dim=128
# Out:
# [2026-02-17 15:03:32] [DEBUG]: Loading preprocessed data...
# [2026-02-17 15:03:32] [DEBUG]: Loaded data: 7425 users, 30954 items
# [2026-02-17 15:03:32] [DEBUG]: Preprocessing data for SASRec...
# [2026-02-17 15:03:32] [DEBUG]: Preprocessing data has finished!
# [2026-02-17 15:03:32] [DEBUG]: Start training...
# [2026-02-17 15:03:32] [DEBUG]: Start epoch 1
# [2026-02-17 15:03:36] [DEBUG]: Epoch 1 completed. Average loss: 0.6270
# [2026-02-17 15:03:36] [DEBUG]: Start epoch 2
# [2026-02-17 15:03:40] [DEBUG]: Epoch 2 completed. Average loss: 0.5474
# [2026-02-17 15:03:40] [DEBUG]: Start epoch 3
# [2026-02-17 15:03:44] [DEBUG]: Epoch 3 completed. Average loss: 0.5256
# [2026-02-17 15:03:44] [DEBUG]: Start epoch 4
# [2026-02-17 15:03:48] [DEBUG]: Epoch 4 completed. Average loss: 0.4886
# [2026-02-17 15:03:48] [DEBUG]: Start epoch 5
# [2026-02-17 15:03:52] [DEBUG]: Epoch 5 completed. Average loss: 0.4396
# [2026-02-17 15:03:52] [DEBUG]: Start epoch 6
# [2026-02-17 15:03:56] [DEBUG]: Epoch 6 completed. Average loss: 0.3900
# [2026-02-17 15:03:56] [DEBUG]: Start epoch 7
# [2026-02-17 15:04:00] [DEBUG]: Epoch 7 completed. Average loss: 0.3495
# [2026-02-17 15:04:00] [DEBUG]: Start epoch 8
# [2026-02-17 15:04:06] [DEBUG]: Epoch 8 completed. Average loss: 0.3168
# [2026-02-17 15:04:06] [DEBUG]: Start epoch 9
# [2026-02-17 15:04:11] [DEBUG]: Epoch 9 completed. Average loss: 0.2899
# [2026-02-17 15:04:11] [DEBUG]: Start epoch 10
# [2026-02-17 15:04:15] [DEBUG]: Epoch 10 completed. Average loss: 0.2654
# [2026-02-17 15:04:15] [DEBUG]: Start epoch 11
# [2026-02-17 15:04:20] [DEBUG]: Epoch 11 completed. Average loss: 0.2468
# [2026-02-17 15:04:20] [DEBUG]: Start epoch 12
# [2026-02-17 15:04:25] [DEBUG]: Epoch 12 completed. Average loss: 0.2286
# [2026-02-17 15:04:25] [DEBUG]: Start epoch 13
# [2026-02-17 15:04:30] [DEBUG]: Epoch 13 completed. Average loss: 0.2134
# [2026-02-17 15:04:30] [DEBUG]: Start epoch 14
# [2026-02-17 15:04:35] [DEBUG]: Epoch 14 completed. Average loss: 0.1993
# [2026-02-17 15:04:35] [DEBUG]: Start epoch 15
# [2026-02-17 15:04:40] [DEBUG]: Epoch 15 completed. Average loss: 0.1875
# [2026-02-17 15:04:40] [DEBUG]: Start epoch 16
# [2026-02-17 15:04:44] [DEBUG]: Epoch 16 completed. Average loss: 0.1774
# [2026-02-17 15:04:44] [DEBUG]: Start epoch 17
# [2026-02-17 15:04:49] [DEBUG]: Epoch 17 completed. Average loss: 0.1678
# [2026-02-17 15:04:49] [DEBUG]: Start epoch 18
# [2026-02-17 15:04:54] [DEBUG]: Epoch 18 completed. Average loss: 0.1595
# [2026-02-17 15:04:54] [DEBUG]: Start epoch 19
# [2026-02-17 15:04:58] [DEBUG]: Epoch 19 completed. Average loss: 0.1521
# [2026-02-17 15:04:58] [DEBUG]: Start epoch 20
# [2026-02-17 15:05:03] [DEBUG]: Epoch 20 completed. Average loss: 0.1449
# [2026-02-17 15:05:03] [DEBUG]: Start epoch 21
# [2026-02-17 15:05:07] [DEBUG]: Epoch 21 completed. Average loss: 0.1389
# [2026-02-17 15:05:07] [DEBUG]: Start epoch 22
# [2026-02-17 15:05:12] [DEBUG]: Epoch 22 completed. Average loss: 0.1328
# [2026-02-17 15:05:12] [DEBUG]: Start epoch 23
# [2026-02-17 15:05:16] [DEBUG]: Epoch 23 completed. Average loss: 0.1283
# [2026-02-17 15:05:16] [DEBUG]: Start epoch 24
# [2026-02-17 15:05:20] [DEBUG]: Epoch 24 completed. Average loss: 0.1230
# [2026-02-17 15:05:20] [DEBUG]: Start epoch 25
# [2026-02-17 15:05:24] [DEBUG]: Epoch 25 completed. Average loss: 0.1182
# [2026-02-17 15:05:24] [DEBUG]: Start epoch 26
# [2026-02-17 15:05:29] [DEBUG]: Epoch 26 completed. Average loss: 0.1149
# [2026-02-17 15:05:29] [DEBUG]: Start epoch 27
# [2026-02-17 15:05:34] [DEBUG]: Epoch 27 completed. Average loss: 0.1109
# [2026-02-17 15:05:34] [DEBUG]: Start epoch 28
# [2026-02-17 15:05:39] [DEBUG]: Epoch 28 completed. Average loss: 0.1080
# [2026-02-17 15:05:39] [DEBUG]: Start epoch 29
# [2026-02-17 15:05:43] [DEBUG]: Epoch 29 completed. Average loss: 0.1043
# [2026-02-17 15:05:43] [DEBUG]: Start epoch 30
# [2026-02-17 15:05:48] [DEBUG]: Epoch 30 completed. Average loss: 0.1024
# [2026-02-17 15:05:48] [DEBUG]: Start epoch 31
# [2026-02-17 15:05:53] [DEBUG]: Epoch 31 completed. Average loss: 0.0990
# [2026-02-17 15:05:53] [DEBUG]: Start epoch 32
# [2026-02-17 15:05:57] [DEBUG]: Epoch 32 completed. Average loss: 0.0956
# [2026-02-17 15:05:57] [DEBUG]: Start epoch 33
# [2026-02-17 15:06:02] [DEBUG]: Epoch 33 completed. Average loss: 0.0939
# [2026-02-17 15:06:02] [DEBUG]: Start epoch 34
# [2026-02-17 15:06:07] [DEBUG]: Epoch 34 completed. Average loss: 0.0915
# [2026-02-17 15:06:07] [DEBUG]: Start epoch 35
# [2026-02-17 15:06:12] [DEBUG]: Epoch 35 completed. Average loss: 0.0899
# [2026-02-17 15:06:12] [DEBUG]: Start epoch 36
# [2026-02-17 15:06:17] [DEBUG]: Epoch 36 completed. Average loss: 0.0875
# [2026-02-17 15:06:17] [DEBUG]: Start epoch 37
# [2026-02-17 15:06:22] [DEBUG]: Epoch 37 completed. Average loss: 0.0865
# [2026-02-17 15:06:22] [DEBUG]: Start epoch 38
# [2026-02-17 15:06:27] [DEBUG]: Epoch 38 completed. Average loss: 0.0849
# [2026-02-17 15:06:27] [DEBUG]: Start epoch 39
# [2026-02-17 15:06:32] [DEBUG]: Epoch 39 completed. Average loss: 0.0841
# [2026-02-17 15:06:32] [DEBUG]: Start epoch 40
# [2026-02-17 15:06:38] [DEBUG]: Epoch 40 completed. Average loss: 0.0816
# [2026-02-17 15:06:38] [DEBUG]: Start epoch 41
# [2026-02-17 15:06:44] [DEBUG]: Epoch 41 completed. Average loss: 0.0800
# [2026-02-17 15:06:44] [DEBUG]: Start epoch 42
# [2026-02-17 15:06:49] [DEBUG]: Epoch 42 completed. Average loss: 0.0792
# [2026-02-17 15:06:49] [DEBUG]: Start epoch 43
# [2026-02-17 15:06:54] [DEBUG]: Epoch 43 completed. Average loss: 0.0775
# [2026-02-17 15:06:54] [DEBUG]: Start epoch 44
# [2026-02-17 15:06:58] [DEBUG]: Epoch 44 completed. Average loss: 0.0771
# [2026-02-17 15:06:58] [DEBUG]: Start epoch 45
# [2026-02-17 15:07:03] [DEBUG]: Epoch 45 completed. Average loss: 0.0755
# [2026-02-17 15:07:03] [DEBUG]: Start epoch 46
# [2026-02-17 15:07:10] [DEBUG]: Epoch 46 completed. Average loss: 0.0751
# [2026-02-17 15:07:10] [DEBUG]: Start epoch 47
# [2026-02-17 15:07:15] [DEBUG]: Epoch 47 completed. Average loss: 0.0732
# [2026-02-17 15:07:15] [DEBUG]: Start epoch 48
# [2026-02-17 15:07:21] [DEBUG]: Epoch 48 completed. Average loss: 0.0726
# [2026-02-17 15:07:21] [DEBUG]: Start epoch 49
# [2026-02-17 15:07:27] [DEBUG]: Epoch 49 completed. Average loss: 0.0723
# [2026-02-17 15:07:27] [DEBUG]: Start epoch 50
# [2026-02-17 15:07:32] [DEBUG]: Epoch 50 completed. Average loss: 0.0708
# [2026-02-17 15:07:32] [DEBUG]: Start epoch 51
# [2026-02-17 15:07:37] [DEBUG]: Epoch 51 completed. Average loss: 0.0706
# [2026-02-17 15:07:37] [DEBUG]: Start epoch 52
# [2026-02-17 15:07:42] [DEBUG]: Epoch 52 completed. Average loss: 0.0696
# [2026-02-17 15:07:42] [DEBUG]: Start epoch 53
# [2026-02-17 15:07:47] [DEBUG]: Epoch 53 completed. Average loss: 0.0687
# [2026-02-17 15:07:47] [DEBUG]: Start epoch 54
# [2026-02-17 15:07:52] [DEBUG]: Epoch 54 completed. Average loss: 0.0683
# [2026-02-17 15:07:52] [DEBUG]: Start epoch 55
# [2026-02-17 15:07:57] [DEBUG]: Epoch 55 completed. Average loss: 0.0678
# [2026-02-17 15:07:57] [DEBUG]: Start epoch 56
# [2026-02-17 15:08:02] [DEBUG]: Epoch 56 completed. Average loss: 0.0670
# [2026-02-17 15:08:02] [DEBUG]: Start epoch 57
# [2026-02-17 15:08:07] [DEBUG]: Epoch 57 completed. Average loss: 0.0665
# [2026-02-17 15:08:07] [DEBUG]: Start epoch 58
# [2026-02-17 15:08:12] [DEBUG]: Epoch 58 completed. Average loss: 0.0654
# [2026-02-17 15:08:12] [DEBUG]: Start epoch 59
# [2026-02-17 15:08:17] [DEBUG]: Epoch 59 completed. Average loss: 0.0659
# [2026-02-17 15:08:17] [DEBUG]: Start epoch 60
# [2026-02-17 15:08:22] [DEBUG]: Epoch 60 completed. Average loss: 0.0647
# [2026-02-17 15:08:22] [DEBUG]: Start epoch 61
# [2026-02-17 15:08:28] [DEBUG]: Epoch 61 completed. Average loss: 0.0639
# [2026-02-17 15:08:28] [DEBUG]: Start epoch 62
# [2026-02-17 15:08:33] [DEBUG]: Epoch 62 completed. Average loss: 0.0640
# [2026-02-17 15:08:33] [DEBUG]: Start epoch 63
# [2026-02-17 15:08:38] [DEBUG]: Epoch 63 completed. Average loss: 0.0632
# [2026-02-17 15:08:38] [DEBUG]: Start epoch 64
# [2026-02-17 15:08:43] [DEBUG]: Epoch 64 completed. Average loss: 0.0631
# [2026-02-17 15:08:43] [DEBUG]: Start epoch 65
# [2026-02-17 15:08:49] [DEBUG]: Epoch 65 completed. Average loss: 0.0632
# [2026-02-17 15:08:49] [DEBUG]: Start epoch 66
# [2026-02-17 15:08:53] [DEBUG]: Epoch 66 completed. Average loss: 0.0617
# [2026-02-17 15:08:53] [DEBUG]: Start epoch 67
# [2026-02-17 15:08:59] [DEBUG]: Epoch 67 completed. Average loss: 0.0616
# [2026-02-17 15:08:59] [DEBUG]: Start epoch 68
# [2026-02-17 15:09:04] [DEBUG]: Epoch 68 completed. Average loss: 0.0611
# [2026-02-17 15:09:04] [DEBUG]: Start epoch 69
# [2026-02-17 15:09:09] [DEBUG]: Epoch 69 completed. Average loss: 0.0612
# [2026-02-17 15:09:09] [DEBUG]: Start epoch 70
# [2026-02-17 15:09:14] [DEBUG]: Epoch 70 completed. Average loss: 0.0611
# [2026-02-17 15:09:14] [DEBUG]: Start epoch 71
# [2026-02-17 15:09:19] [DEBUG]: Epoch 71 completed. Average loss: 0.0592
# [2026-02-17 15:09:19] [DEBUG]: Start epoch 72
# [2026-02-17 15:09:25] [DEBUG]: Epoch 72 completed. Average loss: 0.0600
# [2026-02-17 15:09:25] [DEBUG]: Start epoch 73
# [2026-02-17 15:09:30] [DEBUG]: Epoch 73 completed. Average loss: 0.0592
# [2026-02-17 15:09:30] [DEBUG]: Start epoch 74
# [2026-02-17 15:09:36] [DEBUG]: Epoch 74 completed. Average loss: 0.0590
# [2026-02-17 15:09:36] [DEBUG]: Start epoch 75
# [2026-02-17 15:09:41] [DEBUG]: Epoch 75 completed. Average loss: 0.0580
# [2026-02-17 15:09:41] [DEBUG]: Start epoch 76
# [2026-02-17 15:09:46] [DEBUG]: Epoch 76 completed. Average loss: 0.0581
# [2026-02-17 15:09:46] [DEBUG]: Start epoch 77
# [2026-02-17 15:09:51] [DEBUG]: Epoch 77 completed. Average loss: 0.0596
# [2026-02-17 15:09:51] [DEBUG]: Start epoch 78
# [2026-02-17 15:09:56] [DEBUG]: Epoch 78 completed. Average loss: 0.0582
# [2026-02-17 15:09:56] [DEBUG]: Start epoch 79
# [2026-02-17 15:10:01] [DEBUG]: Epoch 79 completed. Average loss: 0.0579
# [2026-02-17 15:10:01] [DEBUG]: Start epoch 80
# [2026-02-17 15:10:06] [DEBUG]: Epoch 80 completed. Average loss: 0.0585
# [2026-02-17 15:10:06] [DEBUG]: Start epoch 81
# [2026-02-17 15:10:11] [DEBUG]: Epoch 81 completed. Average loss: 0.0577
# [2026-02-17 15:10:11] [DEBUG]: Start epoch 82
# [2026-02-17 15:10:17] [DEBUG]: Epoch 82 completed. Average loss: 0.0569
# [2026-02-17 15:10:17] [DEBUG]: Start epoch 83
# [2026-02-17 15:10:23] [DEBUG]: Epoch 83 completed. Average loss: 0.0565
# [2026-02-17 15:10:23] [DEBUG]: Start epoch 84
# [2026-02-17 15:10:28] [DEBUG]: Epoch 84 completed. Average loss: 0.0566
# [2026-02-17 15:10:28] [DEBUG]: Start epoch 85
# [2026-02-17 15:10:34] [DEBUG]: Epoch 85 completed. Average loss: 0.0557
# [2026-02-17 15:10:34] [DEBUG]: Start epoch 86
# [2026-02-17 15:10:40] [DEBUG]: Epoch 86 completed. Average loss: 0.0559
# [2026-02-17 15:10:40] [DEBUG]: Start epoch 87
# [2026-02-17 15:10:45] [DEBUG]: Epoch 87 completed. Average loss: 0.0559
# [2026-02-17 15:10:45] [DEBUG]: Start epoch 88
# [2026-02-17 15:10:51] [DEBUG]: Epoch 88 completed. Average loss: 0.0554
# [2026-02-17 15:10:51] [DEBUG]: Start epoch 89
# [2026-02-17 15:10:56] [DEBUG]: Epoch 89 completed. Average loss: 0.0545
# [2026-02-17 15:10:56] [DEBUG]: Start epoch 90
# [2026-02-17 15:11:02] [DEBUG]: Epoch 90 completed. Average loss: 0.0564
# [2026-02-17 15:11:02] [DEBUG]: Start epoch 91
# [2026-02-17 15:11:07] [DEBUG]: Epoch 91 completed. Average loss: 0.0556
# [2026-02-17 15:11:07] [DEBUG]: Start epoch 92
# [2026-02-17 15:11:12] [DEBUG]: Epoch 92 completed. Average loss: 0.0555
# [2026-02-17 15:11:12] [DEBUG]: Start epoch 93
# [2026-02-17 15:11:18] [DEBUG]: Epoch 93 completed. Average loss: 0.0547
# [2026-02-17 15:11:18] [DEBUG]: Start epoch 94
# [2026-02-17 15:11:23] [DEBUG]: Epoch 94 completed. Average loss: 0.0552
# [2026-02-17 15:11:23] [DEBUG]: Start epoch 95
# [2026-02-17 15:11:29] [DEBUG]: Epoch 95 completed. Average loss: 0.0549
# [2026-02-17 15:11:29] [DEBUG]: Start epoch 96
# [2026-02-17 15:11:35] [DEBUG]: Epoch 96 completed. Average loss: 0.0544
# [2026-02-17 15:11:35] [DEBUG]: Start epoch 97
# [2026-02-17 15:11:40] [DEBUG]: Epoch 97 completed. Average loss: 0.0540
# [2026-02-17 15:11:40] [DEBUG]: Start epoch 98
# [2026-02-17 15:11:45] [DEBUG]: Epoch 98 completed. Average loss: 0.0534
# [2026-02-17 15:11:45] [DEBUG]: Start epoch 99
# [2026-02-17 15:11:51] [DEBUG]: Epoch 99 completed. Average loss: 0.0536
# [2026-02-17 15:11:51] [DEBUG]: Start epoch 100
# [2026-02-17 15:11:56] [DEBUG]: Epoch 100 completed. Average loss: 0.0536
# [2026-02-17 15:11:56] [DEBUG]: Training procedure has been finished!
# [2026-02-17 15:11:56] [DEBUG]: Saving model...
# [2026-02-17 15:11:56] [DEBUG]: Saved model as checkpoints/sasrec_v2_best_state.pth

# %%
sasrec = SASRec(
    checkpoint_path='checkpoints/sasrec_v2_best_state.pth',
    max_seq_len=64,
    device='cpu',
    batch_size=128
)

sasrec.load_model()

# %%
sasrec.model
# Out:
# SASRecEncoder(
#   (_item_embeddings): Embedding(30955, 128, padding_idx=30954)
#   (_position_embeddings): Embedding(64, 128)
#   (_layernorm): LayerNorm((128,), eps=1e-09, elementwise_affine=True)
#   (_dropout): Dropout(p=0.2, inplace=False)
#   (_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-09, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-09, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
# )

# %%
from tecd_retail_recsys.data import DataPreprocessor
dp = DataPreprocessor(day_begin=1082, day_end=1308, val_days=20, test_days=20, min_user_interactions=1, min_item_interactions=20)
train_df, val_df, test_df = dp.preprocess()
joined = dp.get_grouped_data(train_df, val_df, test_df)
joined['train_val_interactions'] = joined['train_interactions'] + joined['val_interactions']
print(joined.shape)
# Out:
# Starting data preprocessing...
# Loading events from t_ecd_small_partial/dataset/small/retail/events
# Loaded 236,479,226 total events
# Loading items data from t_ecd_small_partial/dataset/small/retail/items.pq
# Loaded 250,171 items with features: ['item_id', 'item_brand_id', 'item_category', 'item_subcategory', 'item_price', 'item_embedding']
# Merged item features. Data shape: (236479226, 12)
# Filtered to 3,758,762 events with action_type='added-to-cart'
# After filtering (min_user_interactions=1, min_item_interactions=20): 3,249,972 events, 84,944 users, 30,954 items
# Created mappings: 84944 users, 30954 items
# Temporal split - Train: days < 1269 (902,543 events), Val: days 1269-1288 (228,339 events), Test: days >= 1289 (223,395 events)
# Users in each part (train, val, test) - 7425
# (7425, 5)

# %%
# Генерация рекомендаций (как и для других моделей)
predictions = sasrec.predict(joined, topn=100, return_scores=False)
joined['sasrec_recs'] = pd.Series(predictions)

# %%
from tecd_retail_recsys.metrics import calculate_metrics

metrics = calculate_metrics(
    joined, 
    model_preds='sasrec_recs', 
    gt_col='val_interactions',
    train_col='train_interactions',
    verbose=True
)
# Out:
# At k=10:
#   MAP@10       = 0.0587
#   NDCG@10      = 0.1720
#   Precision@10 = 0.0696
#   Recall@10    = 0.0226
#
# At k=100:
#   MAP@100       = 0.0229
#   NDCG@100      = 0.1162
#   Precision@100 = 0.0292
#   Recall@100    = 0.0895
#
# Other Metrics:
#   MRR                 = 0.1758
#   Catalog Coverage    = 0.6993
#   Diversity     = 0.9953  [0=same recs for all, 1=unique recs]
#   Novelty             = 0.8733
#   Serendipity         = 0.0362
